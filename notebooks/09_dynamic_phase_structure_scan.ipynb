# %% [markdown]
# # Dynamic persistence-phase structure scan
#
# This notebook scans logarithmic bases continuously and treats all patterns as exploratory. It does not claim a preferred base or physical significance.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.dynamic_phase_structure import generate

# %%
scan, geometry, alignment, relationships = generate()
scan.head()

# %% [markdown]
# ## Inspect scan maxima and persistent relationships

# %%
scan.nlargest(10, "top4_symmetry_score")[["base", "largest_gap_deg", "entropy_bits", "resultant_length_R", "top4_symmetry_score"]]

# %%
relationships.groupby("record_type", group_keys=False).head(10)
