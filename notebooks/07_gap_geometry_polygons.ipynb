# %% [markdown]
# # Gap-center polygon geometry
#
# This notebook connects the centers of the largest circular phase gaps for bases `2`, `e`, `pi`, `phi`, and `10`. The geometry is exploratory and does not imply a physical law or a preferred logarithmic base.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.gap_geometry import generate, load_inputs, geometry_records

# %% [markdown]
# ## Generate summary and figures
#
# The module reads `data/complex_phase_gaps.csv` and `data/complex_phase_table.csv`, computes the requested polygons, writes `data/gap_geometry_summary.csv`, and saves figures under `outputs/gap_geometry/`.

# %%
summary = generate()
summary

# %% [markdown]
# ## Inspect the strongest descriptive symmetry
#
# The score only compares angular spacing with an ideal regular polygon. It is a descriptive screening metric.

# %%
summary.sort_values("symmetry_score", ascending=False).head(10)

# %% [markdown]
# ## Inspect selected gaps

# %%
gaps, _ = load_inputs()
_, selections = geometry_records(gaps)
selections[("10", 4)][["from_entity", "to_entity", "gap_deg", "mid_theta_deg"]]
