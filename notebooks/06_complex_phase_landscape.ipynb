# %% [markdown]
# # Complex Phase Gap Landscape
#
# Exploratory mapping of finite particle persistence cycles into complex phase space. Phase alignment is descriptive and does not imply a physical law.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.complex_phase import generate

phases, gaps, summary = generate()
summary

# %% [markdown]
# ## Generated figures
#
# The generator saves unit-circle and polar plots for each base, frequency-vs-phase, persistence-vs-phase, ranked circular gaps, and a phase-fraction heatmap under `outputs/complex_phase/`.

# %%
from IPython.display import Image, display

for filename in ['unit_circle_base_10.png', 'polar_base_10.png', 'frequency_vs_phase.png', 'persistence_vs_phase.png', 'gap_ranking_top10.png', 'phase_fraction_heatmap.png']:
    display(Image(filename=str(ROOT / 'outputs' / 'complex_phase' / filename)))

# %% [markdown]
# ## Largest gaps by base

# %%
gaps.groupby('base', sort=False).head(10)
